# %%
def Model_G(Weight, Posture):
    
    # Acc_L Model #
    Model_Acc_L_Input = Input(shape=(W,X,Y,Z))

    Model_Acc_L = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Acc_L_Input)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)    
    Model_Acc_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)    
    Model_Acc_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Flatten()))(Model_Acc_L)
    
    
    # Acc_R Model #
    Model_Acc_R_Input = Input(shape=(W,X,Y,Z))

    Model_Acc_R = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Acc_R_Input)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)    
    Model_Acc_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)    
    Model_Acc_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Flatten()))(Model_Acc_R)
    
    
    # Ang_L Model #
    Model_Ang_L_Input = Input(shape=(W,X,Y,Z))

    Model_Ang_L = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Ang_L_Input)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)    
    Model_Ang_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)    
    Model_Ang_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Flatten()))(Model_Ang_L)
    
    
    # Ang_R Model #
    Model_Ang_R_Input = Input(shape=(W,X,Y,Z))

    Model_Ang_R = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Ang_R_Input)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)    
    Model_Ang_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)    
    Model_Ang_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Flatten()))(Model_Ang_R)
    
    
    ## Merge ##
    Merge = concatenate([Model_Acc_L, Model_Acc_R, Model_Ang_L, Model_Ang_R])
    
    
    # Weight Classifier #
    Model_Weight = (LSTM(512))(Merge)
    Model_Weight = (BatchNormalization())(Model_Weight)
    Model_Weight = (Dense(Weight, activation='softmax', name='Model_Weight'))(Model_Weight)


    # Posture Classifier #
    Model_Posture = (LSTM(512))(Merge)
    Model_Posture = (BatchNormalization())(Model_Posture)
    Model_Posturen = (Dense(Posture, activation='softmax', name='Model_Posture'))(Model_Posture)


    # Final Model #
    Model_Final = Model(inputs=[Model_Acc_L_Input, Model_Acc_R_Input, Model_Ang_L_Input, Model_Ang_R_Input], outputs=[Model_Weight, Model_Posture])
    Model_Final.summary()
    Model_Final.compile(optimizer=tensorflow.keras.optimizers.Adam(lr=0.00001), loss={'Model_Weight': 'categorical_crossentropy', 'Model_Posture': 'categorical_crossentropy'}, metrics=['accuracy'])

    return (Model_Final)

# %%
def Model_GL(Weight, Posture):
    
    # Acc_L Model #
    Model_Acc_L_Input = Input(shape=(W,X,Y,Z))

    Model_Acc_L = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Acc_L_Input)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)    
    Model_Acc_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)    
    Model_Acc_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Flatten()))(Model_Acc_L)
    
    
    # Ang_L Model #
    Model_Ang_L_Input = Input(shape=(W,X,Y,Z))

    Model_Ang_L = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Ang_L_Input)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)    
    Model_Ang_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)    
    Model_Ang_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Flatten()))(Model_Ang_L)
    
    
    ## Merge ##
    Merge = concatenate([Model_Acc_L, Model_Ang_L])
    
    
    # Weight Classifier #
    Model_Weight = (LSTM(512))(Merge)
    Model_Weight = (BatchNormalization())(Model_Weight)
    Model_Weight = (Dense(Weight, activation='softmax', name='Model_Weight'))(Model_Weight)


    # Posture Classifier #
    Model_Posture = (LSTM(512))(Merge)
    Model_Posture = (BatchNormalization())(Model_Posture)
    Model_Posture = (Dense(Posture, activation='softmax', name='Model_Posture'))(Model_Posture)


    # Final Model #
    Model_Final = Model(inputs=[Model_Acc_L_Input, Model_Ang_L_Input], outputs=[Model_Weight, Model_Posture])
    Model_Final.summary()
    Model_Final.compile(optimizer=tensorflow.keras.optimizers.Adam(lr=0.00001), loss={'Model_Weight': 'categorical_crossentropy', 'Model_Posture': 'categorical_crossentropy'}, metrics=['accuracy'])

    return (Model_Final)

# %%
def Model_GR(Weight, Posture):
    
    # Acc_R Model #
    Model_Acc_R_Input = Input(shape=(W,X,Y,Z))

    Model_Acc_R = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Acc_R_Input)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)    
    Model_Acc_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)    
    Model_Acc_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Flatten()))(Model_Acc_R)

    
    # Ang_R Model #
    Model_Ang_R_Input = Input(shape=(W,X,Y,Z))

    Model_Ang_R = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Ang_R_Input)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)    
    Model_Ang_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)    
    Model_Ang_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Flatten()))(Model_Ang_R)
    
    
    ## Merge ##
    Merge = concatenate([Model_Acc_R, Model_Ang_R])
    
    
    # Weight Classifier #
    Model_Weight = (LSTM(512))(Merge)
    Model_Weight = (BatchNormalization())(Model_Weight)
    Model_Weight = (Dense(Weight, activation='softmax', name='Model_Weight'))(Model_Weight)


    # Posture Classifier #
    Model_Posture = (LSTM(512))(Merge)
    Model_Posture = (BatchNormalization())(Model_Posture)
    Model_Posture = (Dense(Posture, activation='softmax', name='Model_Posture'))(Model_Posture)


    # Final Model #
    Model_Final = Model(inputs=[Model_Acc_R_Input, Model_Ang_R_Input], outputs=[Model_Weight, Model_Posture])
    Model_Final.summary()
    Model_Final.compile(optimizer=tensorflow.keras.optimizers.Adam(lr=0.00001), loss={'Model_Weight': 'categorical_crossentropy', 'Model_Posture': 'categorical_crossentropy'}, metrics=['accuracy'])

    return (Model_Final)

# %%
def Model_W(Weight, Posture):
    
    # Acc_W Model #
    Model_Acc_W_Input = Input(shape=(W,X,Y,Z))

    Model_Acc_W = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Acc_W_Input)
    Model_Acc_W = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    
    Model_Acc_W = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)    
    Model_Acc_W = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    
    Model_Acc_W = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)    
    Model_Acc_W = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    
    Model_Acc_W = (TimeDistributed(Flatten()))(Model_Acc_W)
    
    
    # Ang_W Model #
    Model_Ang_W_Input = Input(shape=(W,X,Y,Z))

    Model_Ang_W = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Ang_W_Input)
    Model_Ang_W = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    
    Model_Ang_W = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)    
    Model_Ang_W = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    
    Model_Ang_W = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)    
    Model_Ang_W = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    
    Model_Ang_W = (TimeDistributed(Flatten()))(Model_Ang_W)
    
    
    ## Merge ##
    Merge = concatenate([Model_Acc_W, Model_Ang_W])
    
    
    # Weight Classifier #
    Model_Weight = (LSTM(512))(Merge)
    Model_Weight = (BatchNormalization())(Model_Weight)
    Model_Weight = (Dense(Weight, activation='softmax', name='Model_Weight'))(Model_Weight)


    # Posture Classifier #
    Model_Posture = (LSTM(512))(Merge)
    Model_Posture = (BatchNormalization())(Model_Posture)
    Model_Posture = (Dense(Posture, activation='softmax', name='Model_Posture'))(Model_Posture)


    # Final Model #
    Model_Final = Model(inputs=[Model_Acc_W_Input, Model_Ang_W_Input], outputs=[Model_Weight, Model_Posture])
    Model_Final.summary()
    Model_Final.compile(optimizer=tensorflow.keras.optimizers.Adam(lr=0.00001), loss={'Model_Weight': 'categorical_crossentropy', 'Model_Posture': 'categorical_crossentropy'}, metrics=['accuracy'])

    return (Model_Final)

# %%
def Model_GW(Weight, Posture):
    
    # Acc_L Model #
    Model_Acc_L_Input = Input(shape=(W,X,Y,Z))

    Model_Acc_L = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Acc_L_Input)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)    
    Model_Acc_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)    
    Model_Acc_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_L)
    Model_Acc_L = (TimeDistributed(BatchNormalization()))(Model_Acc_L)
    
    Model_Acc_L = (TimeDistributed(Flatten()))(Model_Acc_L)
    
    
    # Acc_R Model #
    Model_Acc_R_Input = Input(shape=(W,X,Y,Z))

    Model_Acc_R = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Acc_R_Input)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)    
    Model_Acc_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)    
    Model_Acc_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_R)
    Model_Acc_R = (TimeDistributed(BatchNormalization()))(Model_Acc_R)
    
    Model_Acc_R = (TimeDistributed(Flatten()))(Model_Acc_R)
    
    
    # Acc_W Model #
    Model_Acc_W_Input = Input(shape=(W,X,Y,Z))

    Model_Acc_W = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Acc_W_Input)
    Model_Acc_W = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    
    Model_Acc_W = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)    
    Model_Acc_W = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    
    Model_Acc_W = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)    
    Model_Acc_W = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Acc_W)
    Model_Acc_W = (TimeDistributed(BatchNormalization()))(Model_Acc_W)
    
    Model_Acc_W = (TimeDistributed(Flatten()))(Model_Acc_W)
    
    
    # Ang_L Model #
    Model_Ang_L_Input = Input(shape=(W,X,Y,Z))

    Model_Ang_L = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Ang_L_Input)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)    
    Model_Ang_L = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)    
    Model_Ang_L = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_L)
    Model_Ang_L = (TimeDistributed(BatchNormalization()))(Model_Ang_L)
    
    Model_Ang_L = (TimeDistributed(Flatten()))(Model_Ang_L)
    
    
    # Ang_R Model #
    Model_Ang_R_Input = Input(shape=(W,X,Y,Z))

    Model_Ang_R = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Ang_R_Input)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)    
    Model_Ang_R = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)    
    Model_Ang_R = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_R)
    Model_Ang_R = (TimeDistributed(BatchNormalization()))(Model_Ang_R)
    
    Model_Ang_R = (TimeDistributed(Flatten()))(Model_Ang_R)
    
    
    # Ang_W Model #
    Model_Ang_W_Input = Input(shape=(W,X,Y,Z))

    Model_Ang_W = (TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001), data_format='channels_first')))(Model_Ang_W_Input)
    Model_Ang_W = (TimeDistributed(MaxPooling2D(pool_size=(3, 3))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    
    Model_Ang_W = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)    
    Model_Ang_W = (TimeDistributed(Conv2D(64, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    
    Model_Ang_W = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)    
    Model_Ang_W = (TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding = 'same', activation='relu', kernel_regularizer=regularizers.l2(0.00001))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(MaxPooling2D(pool_size=(2, 2))))(Model_Ang_W)
    Model_Ang_W = (TimeDistributed(BatchNormalization()))(Model_Ang_W)
    
    Model_Ang_W = (TimeDistributed(Flatten()))(Model_Ang_W)
    
    
    ## Merge ##
    Merge = concatenate([Model_Acc_L, Model_Acc_R, Model_Acc_W, Model_Ang_L, Model_Ang_R, Model_Ang_W])
    
    
    # Weight Classifier #
    Model_Weight = (LSTM(512))(Merge)
    Model_Weight = (BatchNormalization())(Model_Weight)
    Model_Weight = (Dense(Weight, activation='softmax', name='Model_Weight'))(Model_Weight)


    # Posture Classifier #
    Model_Posture = (LSTM(512))(Merge)
    Model_Posture = (BatchNormalization())(Model_Posture)
    Model_Posture = (Dense(Posture, activation='softmax', name='Model_Posture'))(Model_Posture)


    # Final Model #
    Model_Final = Model(inputs=[Model_Acc_L_Input, Model_Acc_R_Input, Model_Acc_W_Input, Model_Ang_L_Input, Model_Ang_R_Input, Model_Ang_W_Input], outputs=[Model_Weight, Model_Posture])
    Model_Final.summary()
    Model_Final.compile(optimizer=tensorflow.keras.optimizers.Adam(lr=0.00001), loss={'Model_Weight': 'categorical_crossentropy', 'Model_Posture': 'categorical_crossentropy'}, metrics=['accuracy'])

    return (Model_Final)

# %%
def Model_Test(Weight, Posture):
    
    Model_W = load_model(Weight)
    Accuracy_W = Model_W.evaluate([Data_Test_Acc, Data_Test_Ang], [Label_Weight_Test_Acc, Label_Posture_Test_Acc])
    
    # Weight #
    Predicted = Model_W.predict([Data_Test_Acc, Data_Test_Ang])
    Predicted = (np.argmax(Predicted[0], axis=1))
    Trued = (np.argmax(Label_Weight_Test_Acc, axis=1))

    ActivityName_Y = ['0.2 kg','13.6 kg','24 kg']
    ActivityName_X = ['24 kg','13.6 kg','0.2 kg']

    ConfusionMatrix = confusion_matrix(Trued, Predicted)
    ConfusionMatrix = ConfusionMatrix.astype('float')/ConfusionMatrix.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(6,6))
    plt.xlabel('Predicted Weight', **LabelFont)
    plt.ylabel('True Weight', **LabelFont)
    plt.yticks(np.linspace(0,2,3), ActivityName_Y, rotation=90, va='center', **UnitFont)
    plt.xticks(np.linspace(2,0,3), ActivityName_X, **UnitFont)
    plt.imshow(ConfusionMatrix, cmap=plt.cm.GnBu)
    plt.clim(0,1)
    
    fmt = '.2f'
    thresh = ConfusionMatrix.max() / 2.
    for i in range(ConfusionMatrix.shape[0]):
        for j in range(ConfusionMatrix.shape[1]):
            plt.text(j, i, format(ConfusionMatrix[i, j],fmt),
                    ha="center", va="center",
                    color="white" if ConfusionMatrix[i, j] > thresh else "black",  **UnitFont)
            
    plt.savefig(Name + '_Weight_CM.png', bbox_inches='tight', dpi=300, transparent = True)
    plt.show()
    
    
    # Posture #
    Model_P = load_model(Posture)
    Accuracy_P = Model_P.evaluate([Data_Test_Acc, Data_Test_Ang], [Label_Weight_Test_Acc, Label_Posture_Test_Acc])
    Predicted = Model_P.predict([Data_Test_Acc, Data_Test_Ang])
    Predicted = (np.argmax(Predicted[1], axis=1))
    Trued = (np.argmax(Label_Posture_Test_Acc, axis=1))

    ActivityName_Y = ['Two-hand','Shoulder']
    ActivityName_X = ['Shoulder','Two-hand']

    ConfusionMatrix = confusion_matrix(Trued, Predicted)
    ConfusionMatrix = ConfusionMatrix.astype('float')/ConfusionMatrix.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(6,6))
    plt.xlabel('Predicted Posture', **LabelFont)
    plt.ylabel('True Posture', **LabelFont)
    plt.yticks(np.linspace(0,1,2), ActivityName_Y, rotation=90, va='center', **UnitFont)
    plt.xticks(np.linspace(1,0,2), ActivityName_X, **UnitFont)
    plt.imshow(ConfusionMatrix, cmap=plt.cm.GnBu)
    plt.clim(0,1)
    
    fmt = '.2f'
    thresh = ConfusionMatrix.max() / 2.
    for i in range(ConfusionMatrix.shape[0]):
        for j in range(ConfusionMatrix.shape[1]):
            plt.text(j, i, format(ConfusionMatrix[i, j],fmt),
                    ha="center", va="center",
                    color="white" if ConfusionMatrix[i, j] > thresh else "black",  **UnitFont)
            
    plt.savefig(Name + '_Posture_CM.png', bbox_inches='tight', dpi=300, transparent = True)
    plt.show()
    
    print('Weight_W_', Accuracy_W[3]*100)
    print('Posture_W_' ,Accuracy_W[4]*100)
    print('Weight_P_', Accuracy_P[3]*100)
    print('Posture_P_' ,Accuracy_P[4]*100)

# %%
def Model_G_Test(Weight, Posture):
    
    Model_W = load_model(Weight)
    Accuracy_W = Model_W.evaluate([Data_Test_Acc_L, Data_Test_Acc_R, Data_Test_Ang_L, Data_Test_Ang_R], [Label_Weight_Test_Acc_L, Label_Posture_Test_Acc_L])
    
    # Weight #
    Predicted = Model_W.predict([Data_Test_Acc_L, Data_Test_Acc_R, Data_Test_Ang_L, Data_Test_Ang_R])
    Predicted = (np.argmax(Predicted[0], axis=1))
    Trued = (np.argmax(Label_Weight_Test_Acc_L, axis=1))

    ActivityName_Y = ['0 Ibs','30 Ibs','50 Ibs']
    ActivityName_X = ['50 Ibs','30 Ibs','0 Ibs']

    ConfusionMatrix = confusion_matrix(Trued, Predicted)
    ConfusionMatrix = ConfusionMatrix.astype('float')/ConfusionMatrix.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(6,6))
    plt.xlabel('Predicted Weight', **LabelFont)
    plt.ylabel('True Weight', **LabelFont)
    plt.yticks(np.linspace(0,2,3), ActivityName_Y, **UnitFont)
    plt.xticks(np.linspace(2,0,3), ActivityName_X, **UnitFont)
    plt.imshow(ConfusionMatrix, cmap=plt.cm.Greys)
    plt.clim(-1,1)
    #plt.colorbar()
    
    fmt = '.2f'
    thresh = ConfusionMatrix.max() / 2.
    for i in range(ConfusionMatrix.shape[0]):
        for j in range(ConfusionMatrix.shape[1]):
            plt.text(j, i, format(ConfusionMatrix[i, j],fmt),
                    ha="center", va="center",
                    color="white" if ConfusionMatrix[i, j] > thresh else "black",  **UnitFont)
            
    plt.savefig(Name + '_Weight_CM.png', bbox_inches='tight', dpi=300, transparent = True)
    plt.show()
    
    
    # Posture #
    Model_P = load_model(Posture)
    Accuracy_P = Model_P.evaluate([Data_Test_Acc_L, Data_Test_Acc_R, Data_Test_Ang_L, Data_Test_Ang_R], [Label_Weight_Test_Acc_L, Label_Posture_Test_Acc_L])
    Predicted = Model_P.predict([Data_Test_Acc_L, Data_Test_Acc_R, Data_Test_Ang_L, Data_Test_Ang_R])
    Predicted = (np.argmax(Predicted[1], axis=1))
    Trued = (np.argmax(Label_Posture_Test_Acc_L, axis=1))

    ActivityName_Y = ['Two-hand','Shoulder']
    ActivityName_X = ['Shoulder','Two-hand']

    ConfusionMatrix = confusion_matrix(Trued, Predicted)
    ConfusionMatrix = ConfusionMatrix.astype('float')/ConfusionMatrix.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(6,6))
    plt.xlabel('Predicted Posture', **LabelFont)
    plt.ylabel('True Posture', **LabelFont)
    plt.yticks(np.linspace(0,1,2), ActivityName_Y, **UnitFont)
    plt.xticks(np.linspace(1,0,2), ActivityName_X, **UnitFont)
    plt.imshow(ConfusionMatrix, cmap=plt.cm.Greys)
    plt.clim(-1,1)
     #plt.colorbar()
    
    fmt = '.2f'
    thresh = ConfusionMatrix.max() / 2.
    for i in range(ConfusionMatrix.shape[0]):
        for j in range(ConfusionMatrix.shape[1]):
            plt.text(j, i, format(ConfusionMatrix[i, j],fmt),
                    ha="center", va="center",
                    color="white" if ConfusionMatrix[i, j] > thresh else "black",  **UnitFont)
            
    plt.savefig(Name + '_Posture_CM.png', bbox_inches='tight', dpi=300, transparent = True)
    plt.show()
    
    print('Weight_W_', Accuracy_W[3]*100)
    print('Posture_W_' ,Accuracy_W[4]*100)
    print('Weight_P_', Accuracy_P[3]*100)
    print('Posture_P_' ,Accuracy_P[4]*100)

# %%
def Model_GW_Test(Weight, Posture):
    
    Model_W = load_model(Weight)
    Accuracy_W = Model_W.evaluate([Data_Test_Acc_L, Data_Test_Acc_R, Data_Test_Acc_W, Data_Test_Ang_L, Data_Test_Ang_R, Data_Test_Ang_W], [Label_Weight_Test_Acc_L, Label_Posture_Test_Acc_L])
    
    # Weight #
    Predicted = Model_W.predict([Data_Test_Acc_L, Data_Test_Acc_R, Data_Test_Acc_W, Data_Test_Ang_L, Data_Test_Ang_R, Data_Test_Ang_W])
    Predicted = (np.argmax(Predicted[0], axis=1))
    Trued = (np.argmax(Label_Weight_Test_Acc_L, axis=1))

    ActivityName_Y = ['0 Ibs','30 Ibs','50 Ibs']
    ActivityName_X = ['50 Ibs','30 Ibs','0 Ibs']

    ConfusionMatrix = confusion_matrix(Trued, Predicted)
    ConfusionMatrix = ConfusionMatrix.astype('float')/ConfusionMatrix.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(6,6))
    plt.xlabel('Predicted Weight', **LabelFont)
    plt.ylabel('True Weight', **LabelFont)
    plt.yticks(np.linspace(0,2,3), ActivityName_Y, **UnitFont)
    plt.xticks(np.linspace(2,0,3), ActivityName_X, **UnitFont)
    plt.imshow(ConfusionMatrix, cmap=plt.cm.Greys)
    plt.clim(-1,1)
    #plt.colorbar()
    
    fmt = '.2f'
    thresh = ConfusionMatrix.max() / 2.
    for i in range(ConfusionMatrix.shape[0]):
        for j in range(ConfusionMatrix.shape[1]):
            plt.text(j, i, format(ConfusionMatrix[i, j],fmt),
                    ha="center", va="center",
                    color="white" if ConfusionMatrix[i, j] > thresh else "black",  **UnitFont)
            
    plt.savefig(Name + '_Weight_CM.png', bbox_inches='tight', dpi=300, transparent = True)
    plt.show()
    
    
    # Posture #
    Model_P = load_model(Posture)
    Accuracy_P = Model_P.evaluate([Data_Test_Acc_L, Data_Test_Acc_R, Data_Test_Acc_W, Data_Test_Ang_L, Data_Test_Ang_R, Data_Test_Ang_W], [Label_Weight_Test_Acc_L, Label_Posture_Test_Acc_L])
    Predicted = Model_P.predict([Data_Test_Acc_L, Data_Test_Acc_R, Data_Test_Acc_W, Data_Test_Ang_L, Data_Test_Ang_R, Data_Test_Ang_W])
    Predicted = (np.argmax(Predicted[1], axis=1))
    Trued = (np.argmax(Label_Posture_Test_Acc_L, axis=1))

    ActivityName_Y = ['Two-hand','Shoulder']
    ActivityName_X = ['Shoulder','Two-hand']

    ConfusionMatrix = confusion_matrix(Trued, Predicted)
    ConfusionMatrix = ConfusionMatrix.astype('float')/ConfusionMatrix.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(6,6))
    plt.xlabel('Predicted Posture', **LabelFont)
    plt.ylabel('True Posture', **LabelFont)
    plt.yticks(np.linspace(0,1,2), ActivityName_Y, **UnitFont)
    plt.xticks(np.linspace(1,0,2), ActivityName_X, **UnitFont)
    plt.imshow(ConfusionMatrix, cmap=plt.cm.Greys)
    plt.clim(-1,1)
    #plt.colorbar()
    
    fmt = '.2f'
    thresh = ConfusionMatrix.max() / 2.
    for i in range(ConfusionMatrix.shape[0]):
        for j in range(ConfusionMatrix.shape[1]):
            plt.text(j, i, format(ConfusionMatrix[i, j],fmt),
                    ha="center", va="center",
                    color="white" if ConfusionMatrix[i, j] > thresh else "black",  **UnitFont)
            
    plt.savefig(Name + '_Posture_CM.png', bbox_inches='tight', dpi=300, transparent = True)
    plt.show()
    
    print('Weight_W_', Accuracy_W[3]*100)
    print('Posture_W_' ,Accuracy_W[4]*100)
    print('Weight_P_', Accuracy_P[3]*100)
    print('Posture_P_' ,Accuracy_P[4]*100)
